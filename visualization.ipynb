# %%
import pandas as pd
#reading the file
xls_file = pd.ExcelFile('Concrete_Data.xls')
xls_file

# %%
# number of sheets in the file
xls_file.sheet_names
# Out:
# ['Sheet1', 'Sheet2', 'Sheet3']

# %%
#converting the sheet into dataframe
df = xls_file.parse('Sheet1')
df
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# 5                                         266.0
# 6                                         380.0
# 7                                         380.0
# 8                                         266.0
# 9                                         475.0
# 10                                        198.6
# 11                                        198.6
# 12                                        427.5
# 13                                        190.0
# 14                                        304.0
# 15                                        380.0
# 16                                        139.6
# 17                                        342.0
# ...

# %%
import matplotlib.pyplot as plt

# ploting the histogram using all the colums in Dataframe
df.plot(kind='hist', alpha=0.5)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),  shadow=True, ncol=2)

# %%
plt.show()

# %% [markdown]
# ### 1.1) Plot histograms of the attributes. To determine the number of bins use at least three different methods introduced in the lectures (Sturges’ rule, Scott’s rule, square-choice, FreedmanDiaconis rule). Compare the results.

# %% [markdown]
# #### I choosed auto , square-choice and Sturges’ rule

# %% [markdown]
# ##### A: 'auto' using 5 componets in the following plot

# %% [markdown]
# #### Sturges’ rule, Scott’s rule, square-choice rule for selecting the optimal bin width for a histogram.

# %%
df.hist(column='Blast Furnace Slag (component 2)(kg in a m^3 mixture)', bins='auto',histtype='stepfilled', alpha=0.3, normed=True)
df.hist(column='Cement (component 1)(kg in a m^3 mixture)', bins='auto',histtype='stepfilled', alpha=0.3, normed=True)
df.hist(column='Fly Ash (component 3)(kg in a m^3 mixture)', bins='auto',histtype='stepfilled', alpha=0.3, normed=True)
df.hist(column='Water  (component 4)(kg in a m^3 mixture)', bins='auto',histtype='stepfilled', alpha=0.3, normed=True)
df.hist(column='Superplasticizer (component 5)(kg in a m^3 mixture)', bins='auto',histtype='stepfilled', alpha=0.3, normed=True)
df.hist(column='Coarse Aggregate  (component 6)(kg in a m^3 mixture)', bins='auto',histtype='stepfilled', alpha=0.3, normed=True)
df.hist(column='Fine Aggregate (component 7)(kg in a m^3 mixture)', bins='auto',histtype='stepfilled', alpha=0.3, normed=True)
#plt.title("Histogram with 'auto' bins")
#plt.xlabel("Blast Furnace Slag ")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B8403F6208>]], dtype=object)

# %%
plt.show()
#plt.hist(a, bins='auto')

# %% [markdown]
# ##### A: using bins= 'auto ' 3 component in same histogram

# %%
xc= df['Cement (component 1)(kg in a m^3 mixture)']
x1=xc.values
xb= df['Blast Furnace Slag (component 2)(kg in a m^3 mixture)']
x2=xb.values
xf= df['Fly Ash (component 3)(kg in a m^3 mixture)']
x3=xf.values
xw=df['Water  (component 4)(kg in a m^3 mixture)']
x4=xw.values
xs= df['Superplasticizer (component 5)(kg in a m^3 mixture)']
x5=xs.values
xco= df['Coarse Aggregate  (component 6)(kg in a m^3 mixture)']
x6=xco.values
xfi= df['Fine Aggregate (component 7)(kg in a m^3 mixture)']
x7=xfi.values

# %%
x7
# Out:
# array([ 676. ,  676. ,  594. , ...,  780. ,  788.9,  761.5])

# %%
plt.hist(x1, bins = 'auto',histtype='stepfilled', alpha=0.3,color = 'red', normed=True)
plt.hist(x2, bins = 'auto',histtype='stepfilled', alpha=0.3,color = 'green', normed=True)
plt.hist(x3, bins = 'auto',histtype='stepfilled', alpha=0.3,color = 'blue',normed=True)
plt.show()

# %% [markdown]
# ##### A: bins = 13 using component 2(auto)

# %% [markdown]
# ###### Histogram : it is similar to bar chars ,but a histogram groups the  numbers into range.
#     (from below you can see x2values  rage from 0 to 359.5)
#     counts:number of  elements in each bin(ex:540 elements in 1st bin ,41 in second bin ...)
#     bin_edges:edges of bars(ex:in first bar 0 is one edge 27.64 is other edge of the bar(this means from 0-27.64 there
#     are  540 numbers in that range ) , in second bar it started at 27.64 so that is one edge and other is 55.29...)
#
#         bin range            count
#         0---27.64               540
#         27.64---55.29           41
#         55.29---82.93           10
#         82.93---110.58          80
#         .......                 ...
#         ......                  ...

# %%
print(min(x2))
print(max(x2))
# Out:
# 0.0
# 359.4

# %%
import math
import numpy as np
counts, bin_edges = np.histogram(x2, bins = 'auto')
plt.hist(x2, bins = 'auto')
print(counts)
print(bin_edges)
plt.show()
print("Bins: {:3}".format(len(counts)))
# Out:
# [540  41  10  80  85  72 103  42  22  15  10   6   4]
# [   0.           27.64615385   55.29230769   82.93846154  110.58461538
#   138.23076923  165.87692308  193.52307692  221.16923077  248.81538462
#   276.46153846  304.10769231  331.75384615  359.4       ]
# Bins:  13

# %%
plt.figure(figsize=(10,10))
ax1 = plt.subplot(421)
ax1.set_xlabel('Cement (component 1)')

ax2 = plt.subplot(422)
ax2.set_xlabel('Blast Furnace Slag (component 2)')

ax3 = plt.subplot(423)
ax3.set_xlabel('Fly Ash (component 3)')

ax4 = plt.subplot(424)
ax4.set_xlabel('Water  (component 4)')

ax5 = plt.subplot(425)
ax5.set_xlabel('Superplasticizer (component 5)')

ax6 = plt.subplot(426)
ax6.set_xlabel('Coarse Aggregate  (component 6)')

ax7 = plt.subplot(427)
ax7.set_xlabel('Fine Aggregate (component 7)')



ax1.hist(df['Cement (component 1)(kg in a m^3 mixture)'])
ax2.hist(df['Blast Furnace Slag (component 2)(kg in a m^3 mixture)'])
ax3.hist(df['Fly Ash (component 3)(kg in a m^3 mixture)'])
ax4.hist(df['Water  (component 4)(kg in a m^3 mixture)'])
ax5.hist(df['Superplasticizer (component 5)(kg in a m^3 mixture)'])
ax6.hist(df['Coarse Aggregate  (component 6)(kg in a m^3 mixture)'])
ax7.hist(df['Fine Aggregate (component 7)(kg in a m^3 mixture)'])


plt.tight_layout()
plt.show()

# %% [markdown]
# ##### A: Using square-choice ( bins =33) for component 2

# %%
import math
import numpy as np
x= df['Blast Furnace Slag (component 2)(kg in a m^3 mixture)']
x
y=x.values
valx=len(y)
valx
# Out:
# 1030

# %%
binsizes = math.ceil(math.sqrt(valx))
plt.hist(x2, bins = int(binsizes))

counts, bin_edges = np.histogram(x2, bins = int(binsizes))
plt.title("Histogram with 'Sqrt' bins")
plt.xlabel("Blast Furnace Slag ")
plt.show()
print(counts)
print("Bins: {:3}".format(len(counts)))
print(bin_edges)
print(binsizes)
# Out:
# [471  39  30  14  22   5  10   1  35  43  36  29  29  37  23  27  24  57
#   17  24   0  20   8   2   5   6   6   0   4   2   0   2   2]
# Bins:  33
# [   0.           10.89090909   21.78181818   32.67272727   43.56363636
#    54.45454545   65.34545455   76.23636364   87.12727273   98.01818182
#   108.90909091  119.8         130.69090909  141.58181818  152.47272727
#   163.36363636  174.25454545  185.14545455  196.03636364  206.92727273
#   217.81818182  228.70909091  239.6         250.49090909  261.38181818
#   272.27272727  283.16363636  294.05454545  304.94545455  315.83636364
#   326.72727273  337.61818182  348.50909091  359.4       ]
# 33

# %%
plt.figure(figsize=(10,10))
ax1 = plt.subplot(421)
ax1.set_xlabel('Cement (component 1)')

ax2 = plt.subplot(422)
ax2.set_xlabel('Blast Furnace Slag (component 2)')

ax3 = plt.subplot(423)
ax3.set_xlabel('Fly Ash (component 3)')

ax4 = plt.subplot(424)
ax4.set_xlabel('Water  (component 4)')

ax5 = plt.subplot(425)
ax5.set_xlabel('Superplasticizer (component 5)')

ax6 = plt.subplot(426)
ax6.set_xlabel('Coarse Aggregate  (component 6)')

ax7 = plt.subplot(427)
ax7.set_xlabel('Fine Aggregate (component 7)')

ax1.hist(x1, bins = int(binsizes))
ax2.hist(x2, bins = int(binsizes))
ax3.hist(x3, bins = int(binsizes))
ax4.hist(x4, bins = int(binsizes))
ax5.hist(x5, bins = int(binsizes))
ax6.hist(x4, bins = int(binsizes))
ax7.hist(x5, bins = int(binsizes))

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### A: Sturges rule (bins= 12) component 2

# %%
binsize=math.ceil(1+math.log2(valx))
counts, bin_edges = np.histogram(x2, bins = int(binsize))
plt.hist(x2, bins = int(binsize),label='Blast Furnace Slag')
#plt.plot([], [], ' ', label= len(counts))
plt.title("Histogram with 'Sturges rule' bins")
plt.legend(loc='upper center', )
plt.xlabel("Blast Furnace Slag ")
plt.show()

counts, bin_edges = np.histogram(x2, bins = int(binsize))
print(counts)
print("Bins: {:3}".format(len(counts)))
print(bin_edges)
print(binsize)
# Out:
# [540  41  11 114  90  65  97  35  15  12   6   4]
# Bins:  12
# [   0.     29.95   59.9    89.85  119.8   149.75  179.7   209.65  239.6
#   269.55  299.5   329.45  359.4 ]
# 12

# %%
plt.figure(figsize=(10,10))
ax1 = plt.subplot(421)
ax1.set_xlabel('Cement (component 1)')

ax2 = plt.subplot(422)
ax2.set_xlabel('Blast Furnace Slag (component 2)')

ax3 = plt.subplot(423)
ax3.set_xlabel('Fly Ash (component 3)')

ax4 = plt.subplot(424)
ax4.set_xlabel('Water  (component 4)')

ax5 = plt.subplot(425)
ax5.set_xlabel('Superplasticizer (component 5)')

ax6 = plt.subplot(426)
ax6.set_xlabel('Coarse Aggregate  (component 6)')

ax7 = plt.subplot(427)
ax7.set_xlabel('Fine Aggregate (component 7)')

ax1.hist(x1, bins = int(binsize))
ax2.hist(x2, bins = int(binsize))
ax3.hist(x3, bins = int(binsize))
ax4.hist(x4, bins = int(binsize))
ax5.hist(x5, bins = int(binsize))
ax6.hist(x4, bins = int(binsize))
ax7.hist(x5, bins = int(binsize))


plt.tight_layout()
plt.show()

# %%
df.plot(kind='scatter', x='Cement (component 1)(kg in a m^3 mixture)', y='Concrete compressive strength(MPa, megapascals) ')
df.plot(kind='scatter', x='Blast Furnace Slag (component 2)(kg in a m^3 mixture)', y='Concrete compressive strength(MPa, megapascals) ')
df.plot(kind='scatter', x='Fly Ash (component 3)(kg in a m^3 mixture)', y='Concrete compressive strength(MPa, megapascals) ')
df.plot(kind='scatter', x='Water  (component 4)(kg in a m^3 mixture)', y='Concrete compressive strength(MPa, megapascals) ')
df.plot(kind='scatter', x='Superplasticizer (component 5)(kg in a m^3 mixture)', y='Concrete compressive strength(MPa, megapascals) ')
df.plot(kind='scatter', x='Coarse Aggregate  (component 6)(kg in a m^3 mixture)', y='Concrete compressive strength(MPa, megapascals) ')
df.plot(kind='scatter', x='Fine Aggregate (component 7)(kg in a m^3 mixture)', y='Concrete compressive strength(MPa, megapascals) ')
plt.show()

# %%
y=df['Concrete compressive strength(MPa, megapascals) ']


plt.figure(figsize=(10,10))

ax1=plt.subplot(421)
ax1.set_xlabel('Cement (component 1)')
ax1.scatter(x1, y)

ax2=plt.subplot(422)
ax2.set_xlabel('Blast Furnace Slag (component 2)')
ax2.scatter(x2, y)


ax3=plt.subplot(423)
ax3.set_xlabel('Fly Ash (component 3)')
ax3.scatter(x3, y)

ax4=plt.subplot(424)
ax4.set_xlabel('Water  (component 4)')
ax4.scatter(x4, y)

ax5=plt.subplot(425)
ax5.set_xlabel('Superplasticizer (component 5)')
ax5.scatter(x5, y)

ax6=plt.subplot(426)
ax6.set_xlabel('Coarse Aggregate  (component 6)')
ax6.scatter(x6, y)

ax7=plt.subplot(427)
ax7.set_xlabel('Fine Aggregate (component 7)')
ax7.scatter(x7, y)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(100,100))
fig, ax = plt.subplots()
ax.scatter(x1, y, label="Cement (component 1)")
ax.scatter(x2, y, label="Blast Furnace Slag (component 2)")
ax.scatter(x3, y, label="Fly Ash (component 3)")
ax.scatter(x4, y, label="Water  (component 4)")
ax.scatter(x3, y, label="Superplasticizer (component 5)")
ax.scatter(x4, y, label="Coarse Aggregate  (component 6)")
ax.scatter(x3, y, label="Fine Aggregate (component 7)")

#ax.legend()
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),  shadow=True, ncol=2)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.tools.plotting import parallel_coordinates
plt.figure(figsize=(20,6))
df.columns=["component1","component2","component3","component4","component5","component6","component7","component8","Name"]
#plt.figure()
parallel_coordinates(df,"Name")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),  shadow=True, ncol=2)
plt.show()
# Out:
# C:\Users\harit\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: 'pandas.tools.plotting.parallel_coordinates' is deprecated, import 'pandas.plotting.parallel_coordinates' instead.
#   import sys
